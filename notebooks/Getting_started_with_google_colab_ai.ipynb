# %% [markdown]
# <a href="https://colab.research.google.com/github/bdat2k6-cell/Nh-n-Di-n-Nh-ng-H-nh-Vi-Kh-ng-Chu-n-M-c-Trong-L-p-H-c/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Colab is making it easier than ever to integrate powerful Generative AI capabilities into your projects. We are launching public preview for a simple and intuitive Python library (google.colab.ai) to access state-of-the-art language models directly within Colab environments. All users have free access to most popular LLMs, while paid users have access to a wider selection of models. This means users can spend less time on configuration and set up and more time bringing their ideas to life. With just a few lines of code, you can now perform a variety of tasks:
# - Generate text
# - Translate languages
# - Write creative content
# - Categorize text
#
# Happy Coding!
#
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# @title List available models
from google.colab import ai

ai.list_models()
# Out:
# ['google/gemini-2.5-flash', 'google/gemini-2.5-flash-lite']

# %% [markdown]
# Choosing a Model
# The model names give you a hint about their capabilities and intended use:
#
# Pro: These are the most capable models, ideal for complex reasoning, creative tasks, and detailed analysis.
#
# Flash: These models are optimized for high speed and efficiency, making them great for summarization, chat applications, and tasks requiring rapid responses.
#
# Gemma: These are lightweight, open-weight models suitable for a variety of text generation tasks and are great for experimentation.

# %%
# @title Simple batch generation example
# Only text-to-text input/output is supported
from google.colab import ai # Nhập thư viện 'ai' từ 'google.colab' để truy cập các tính năng AI của Colab.

response = ai.generate_text("What is the capital of France?") # Gọi hàm 'generate_text' từ thư viện 'ai' để tạo văn bản. Đây là một lời gọi đơn giản để tạo ra phản hồi cho một câu hỏi nhất định.
print(response) # In kết quả văn bản mà mô hình AI đã tạo ra màn hình.
# Out:
# The capital of France is **Paris**.

# %%
# @title Choose a different model
from google.colab import ai

response = ai.generate_text("Liệt kê một số hành vi không chuẩn mực trong lớp học", model_name='google/gemini-2.5-flash-lite')
print(response)
# Out:
# Dưới đây là một số hành vi không chuẩn mực trong lớp học, được phân loại để dễ hiểu hơn:
#
# **1. Hành vi gây ảnh hưởng tiêu cực đến việc học tập của bản thân và người khác:**
#
# *   **Nói chuyện riêng, cười đùa ồn ào:** Làm gián đoạn bài giảng, gây mất tập trung cho giáo viên và các bạn cùng lớp.
# *   **Sử dụng điện thoại di động không đúng mục đích:** Lướt mạng xã hội, chơi game, nhắn tin trong giờ học làm sao nhãng việc tiếp thu kiến thức.
# *   **Ăn uống, làm việc riêng:** Gây tiếng động, mùi khó chịu hoặc đơn giản là không tập trung vào bài học.
# *   **Ngủ gật, thiếu tập trung:** Thể hiện sự mệt mỏi, không quan tâm đến bài giảng.
# *   **Đi lại trong lớp khi không cần thiết:** Gây xáo trộn và mất trật tự.
# *   **Nhìn bài, trao đổi bài khi kiểm tra/thi cử:** Gian lận trong học tập.
# *   **Không chuẩn bị bài hoặc không làm bài tập về nhà:** Ảnh hưởng đến tiến độ chung của lớp và khả năng tiếp thu kiến thức.
# *   **Phá hoại tài sản của lớp học hoặc của người khác:** Làm hư hỏng bàn ghế, sách vở, thiết bị.
#
# **2. Hành vi thiếu tôn trọng giáo viên và bạn bè:**
#
# *   **Ngắt lời giáo viên hoặc bạn bè khi họ đang nói:** Thiếu lịch sự và tôn trọng.
# *   **Sử dụng ngôn ngữ thiếu văn hóa, chửi thề, nói tục:** Gây phản cảm và ảnh hưởng đến môi trường học tập.
# *   **Chế giễu, bắt nạt, trêu chọc bạn bè:** Gây tổn thương tinh thần và tạo ra môi trường học tập căng thẳng.
# *   **Có thái độ coi thường, không hợp tác với giáo viên:** Phản kháng, cãi lại một cách vô lý.
# *   **Nói xấu, lan truyền tin đồn về giáo viên hoặc bạn bè:** Gây mất đoàn kết và ảnh hưởng xấu đến danh dự người khác.
# *   **Có những cử chỉ, hành động không phù hợp:** Chẳng hạn như chế nhạo, giễu cợt.
#
# **3. Hành vi phá vỡ quy tắc và nội quy lớp học:**
#
# *   **Đi học muộn hoặc về sớm mà không có lý do chính đáng:** Thể hiện sự thiếu kỷ luật.
# *   **Ăn mặc không đúng quy định của nhà trường/lớp học:** Gây ảnh hưởng đến hình ảnh chung.
# *   **Ra vào lớp khi chưa được phép:** Thiếu ý thức tuân thủ quy định.
# *   **Gây rối, làm ồn ào ở khu vực ngoài lớp học:** Ảnh hưởng đến các lớp học khác.
# *   **Tự ý sử dụng các thiết bị của lớp học khi không được phép:** Gây hư hỏng hoặc sử dụng sai mục đích.
#
# **4. Hành vi tiêu cực thể hiện thái độ cá nhân:**
#
# *   **Luôn tìm cách trốn tránh trách nhiệm:** Không tham gia hoạt động chung, không nhận nhiệm vụ.
# *   **Thường xuyên than phiền, kêu ca:** Tạo ra không khí tiêu cực.
# *   **Thể hiện sự bất mãn, khó chịu một cách lộ liễu:** Làm ảnh hưởng đến tâm trạng chung.
#
# Đây là một số ví dụ phổ biến. Tùy thuộc vào từng môi trường giáo dục và quy định cụ thể của từng trường, các hành vi này có thể được đánh giá khác nhau về mức độ nghiêm trọng. Mục tiêu của việc nhận diện các hành vi không chuẩn mực là để tạo ra một môi trường học tập lành mạnh, hiệu quả và tôn trọng lẫn nhau cho tất cả mọi người.

# %% [markdown]
# For longer text generations, you can stream the response. This displays the output token by token as it's generated, rather than waiting for the entire response to complete. This provides a more interactive and responsive experience. To enable this, simply set stream=True.

# %%
# @title Simple streaming example
from google.colab import ai

stream = ai.generate_text("Liệt kê chi tiết và giải thích một số hành vi không chuẩn mực trong lớp học.", stream=True)
for text in stream:
  print(text, end='')
# Out:
# Hành vi không chuẩn mực trong lớp học là những hành động hoặc thái độ của học sinh đi chệch khỏi các quy tắc, chuẩn mực đạo đức, và kỳ vọng về ứng xử trong môi trường giáo dục. Những hành vi này có thể gây ảnh hưởng tiêu cực đến không khí học tập, quá trình giảng dạy và sự phát triển của cả cá nhân học sinh cũng như tập thể lớp.
#
# Dưới đây là một số hành vi không chuẩn mực phổ biến, kèm theo giải thích chi tiết:
#
# ---
#
# **I. Nhóm hành vi gây rối trật tự và ảnh hưởng đến việc giảng dạy**
#
# 1.  **Nói chuyện riêng/Làm ồn trong giờ học:**
#     *   **Giải thích:** Đây là hành vi rất phổ biến. Học sinh nói chuyện riêng về các chủ đề không liên quan đến bài học, cười đùa lớn tiếng, hoặc gây ra các tiếng động làm sao nhãng người khác (ví dụ: gõ bút, lật sách ồn ào).
#     *   **Tác động:**
#         *   **Với giáo viên:** Phân tán sự chú ý, làm gián đoạn dòng chảy bài giảng, khiến giáo viên phải dừng lại để nhắc nhở, lãng phí thời gian.
#         *   **Với học sinh khác:** Gây khó chịu, khó tập trung nghe giảng, làm giảm hiệu quả tiếp thu kiến thức.
#         *   **Với bản thân học sinh:** Bỏ lỡ thông tin quan trọng, không nắm bắt được bài học.
#
# 2.  **Đi lại tự do, ra vào lớp không xin phép:**
#     *   **Giải thích:** Học sinh đứng dậy khỏi chỗ ngồi mà không có lý do chính đáng hoặc không được phép, đi lại trong lớp, ra ngoài (đi vệ sinh, uống nước...) mà không xin phép giáo viên.
#     *   **Tác động:**
#         *   **Với giáo viên:** Gây mất kiểm soát lớp học, làm phân tâm khi đang giảng bài.
#         *   **Với học sinh khác:** Làm gián đoạn tầm nhìn, gây chú ý, ảnh hưởng đến sự tập trung.
#         *   **Với bản thân học sinh:** Bỏ lỡ nội dung bài học, tạo thói quen tùy tiện.
#
# 3.  **Ăn uống trong giờ học:**
#     *   **Giải thích:** Học sinh ăn vặt, nhai kẹo cao su, uống nước ngọt (ngoại trừ nước lọc khi cần thiết) trong khi giáo viên đang giảng bài hoặc trong thời gian học tập.
#     *   **Tác động:**
#         *   **Với giáo viên:** Thể hiện sự thiếu tôn trọng, gây mất mỹ quan và vệ sinh lớp học.
#         *   **Với học sinh khác:** Gây phân tán sự chú ý bởi mùi vị hoặc tiếng động khi ăn uống, đôi khi là cảm giác thèm muốn.
#         *   **Với bản thân học sinh:** Không tập trung vào bài học, có thể làm bẩn sách vở, bàn ghế.
#
# ---
#
# **II. Nhóm hành vi thiếu tôn trọng và vô kỷ luật**
#
# 1.  **Không tuân thủ nội quy lớp học/nhà trường:**
#     *   **Giải thích:** Không làm bài tập về nhà, không nộp bài đúng hạn, không mặc đúng đồng phục, đến muộn, sử dụng điện thoại khi không được phép, v.v.
#     *   **Tác động:**
#         *   **Với giáo viên/nhà trường:** Gây khó khăn trong việc quản lý, duy trì kỷ luật, làm giảm hiệu quả giảng dạy và đánh giá.
#         *   **Với học sinh khác:** Tạo tiền lệ xấu, khiến các học sinh khác có thể noi theo.
#         *   **Với bản thân học sinh:** Ảnh hưởng trực tiếp đến kết quả học tập, rèn luyện, hình thành thói quen vô trách nhiệm.
#
# 2.  **Thiếu tôn trọng giáo viên và bạn bè:**
#     *   **Giải thích:**
#         *   **Với giáo viên:** Cãi lại giáo viên một cách vô lễ, cắt lời khi giáo viên đang nói, có thái độ thách thức, chế nhạo, hoặc bỏ qua lời nhắc nhở.
#         *   **Với bạn bè:** Chế nhạo, đặt biệt danh xấu, nói xấu, xúc phạm, cười cợt khi bạn bè phát biểu hoặc mắc lỗi.
#     *   **Tác động:**
#         *   **Với giáo viên:** Gây ức chế, ảnh hưởng đến tinh thần giảng dạy, làm giảm uy tín.
#         *   **Với học sinh khác:** Tạo môi trường học tập tiêu cực, căng thẳng, thiếu an toàn, tổn thương tâm lý.
#         *   **Với bản thân học sinh:** Thể hiện sự thiếu văn hóa, khó hòa nhập, có thể bị cô lập, làm mất đi sự tôn trọng từ người khác.
#
# 3.  **Sử dụng ngôn ngữ không phù hợp (tục tĩu, chửi thề):**
#     *   **Giải thích:** Sử dụng từ ngữ thô tục, chửi thề khi giao tiếp với bạn bè hoặc thậm chí với giáo viên (dù có thể là vô ý hoặc bộc phát).
#     *   **Tác động:**
#         *   **Với môi trường chung:** Làm ô nhiễm môi trường giao tiếp, tạo cảm giác khó chịu, thiếu văn minh.
#         *   **Với học sinh khác:** Gây ảnh hưởng xấu đến nhận thức và hành vi của các bạn khác, đặc biệt là các em nhỏ hơn.
#         *   **Với bản thân học sinh:** Hình thành thói quen giao tiếp xấu, bị đánh giá thấp về phẩm chất đạo đức.
#
# ---
#
# **III. Nhóm hành vi gian lận và thiếu trung thực**
#
# 1.  **Gian lận trong kiểm tra, thi cử:**
#     *   **Giải thích:** Quay cóp, chép bài của bạn, sử dụng tài liệu không được phép, nhờ người khác làm hộ bài kiểm tra, hoặc sử dụng thiết bị điện tử để tìm kiếm đáp án.
#     *   **Tác động:**
#         *   **Với giáo dục:** Làm mất đi tính công bằng, chính xác của việc đánh giá năng lực học sinh.
#         *   **Với học sinh khác:** Gây sự bất mãn, cảm giác không công bằng cho những học sinh trung thực.
#         *   **Với bản thân học sinh:** Không phản ánh đúng năng lực, không tự mình rèn luyện kiến thức, hình thành thói quen dựa dẫm, thiếu trung thực, ảnh hưởng xấu đến sự phát triển nhân cách.
#
# 2.  **Đạo văn, sao chép bài tập/đề án:**
#     *   **Giải thích:** Chép nguyên văn bài làm của người khác hoặc tài liệu từ internet mà không ghi rõ nguồn, trình bày như của mình.
#     *   **Tác động:** Tương tự như gian lận, làm mất đi giá trị của sự sáng tạo, tư duy độc lập và trung thực trong học tập.
#
# ---
#
# **IV. Nhóm hành vi gây hại thể chất/tinh thần**
#
# 1.  **Bắt nạt (trực tiếp và trực tuyến):**
#     *   **Giải thích:**
#         *   **Trực tiếp:** Đánh đập, xô đẩy, dọa nạt, cô lập bạn bè, cướp đồ, trêu chọc ác ý, bêu xấu.
#         *   **Trực tuyến (Cyberbullying):** Tung tin đồn thất thiệt, đăng ảnh/video chế giễu, bình luận tiêu cực trên mạng xã hội, quấy rối qua tin nhắn.
#     *   **Tác động:**
#         *   **Với nạn nhân:** Gây tổn thương nghiêm trọng về thể chất và tinh thần (sợ hãi, lo âu, trầm cảm, giảm sút học tập, tự kỷ...), thậm chí có thể dẫn đến những hành vi tự hủy hoại.
#         *   **Với người bắt nạt:** Hình thành tính cách hung hăng, thiếu đồng cảm, có thể dẫn đến các hành vi phạm pháp lớn hơn trong tương lai.
#         *   **Với môi trường lớp học:** Tạo không khí sợ hãi, thiếu an toàn, mất đoàn kết.
#
# 2.  **Phá hoại tài sản chung hoặc của người khác:**
#     *   **Giải thích:** Vẽ bậy lên bàn ghế, tường, làm hỏng các thiết bị học tập, làm rách sách vở của bạn, v.v.
#     *   **Tác động:** Gây thiệt hại về vật chất, ảnh hưởng đến môi trường học tập, thể hiện sự thiếu ý thức, thiếu trách nhiệm với cộng đồng.
#
# ---
#
# **V. Nhóm hành vi thiếu ý thức và trách nhiệm**
#
# 1.  **Thiếu chuẩn bị đồ dùng học tập:**
#     *   **Giải thích:** Quên sách vở, bút, thước, hoặc các dụng cụ học tập cần thiết khác, khiến phải mượn của bạn hoặc không thể hoàn thành bài tập.
#     *   **Tác động:**
#         *   **Với bản thân:** Ảnh hưởng đến khả năng tiếp thu bài, gây gián đoạn quá trình học tập.
#         *   **Với bạn bè:** Gây phiền phức, làm mất thời gian của bạn khi phải cho mượn.
#
# 2.  **Không giữ gìn vệ sinh chung:**
#     *   **Giải thích:** Xả rác bừa bãi trong lớp, không dọn dẹp sau khi ăn uống, làm bẩn bàn ghế, v.v.
#     *   **Tác động:** Gây mất vệ sinh, ảnh hưởng đến sức khỏe, làm giảm mỹ quan và sự thoải mái của môi trường học tập.
#
# ---
#
# **Tổng kết:**
#
# Việc nhận diện và giải thích chi tiết các hành vi không chuẩn mực này giúp giáo viên, phụ huynh và cả học sinh hiểu rõ hơn về tác động tiêu cực của chúng. Từ đó, có thể đưa ra các biện pháp giáo dục, răn đe và hỗ trợ phù hợp để xây dựng một môi trường học tập lành mạnh, tích cực và hiệu quả.

# %%
#@title Text formatting setup
#code is not necessary for colab.ai, but is useful in fomatting text chunks
import sys

class LineWrapper:
    def __init__(self, max_length=80):
        self.max_length = max_length
        self.current_line_length = 0

    def print(self, text_chunk):
        i = 0
        n = len(text_chunk)
        while i < n:
            start_index = i
            while i < n and text_chunk[i] not in ' \n': # Find end of word
                i += 1
            current_word = text_chunk[start_index:i]

            delimiter = ""
            if i < n: # If not end of chunk, we found a delimiter
                delimiter = text_chunk[i]
                i += 1 # Consume delimiter

            if current_word:
                needs_leading_space = (self.current_line_length > 0)

                # Case 1: Word itself is too long for a line (must be broken)
                if len(current_word) > self.max_length:
                    if needs_leading_space: # Newline if current line has content
                        sys.stdout.write('\n')
                        self.current_line_length = 0
                    for char_val in current_word: # Break the long word
                        if self.current_line_length >= self.max_length:
                            sys.stdout.write('\n')
                            self.current_line_length = 0
                        sys.stdout.write(char_val)
                        self.current_line_length += 1
                # Case 2: Word doesn't fit on current line (print on new line)
                elif self.current_line_length + (1 if needs_leading_space else 0) + len(current_word) > self.max_length:
                    sys.stdout.write('\n')
                    sys.stdout.write(current_word)
                    self.current_line_length = len(current_word)
                # Case 3: Word fits on current line
                else:
                    if needs_leading_space:
                        # Define punctuation that should not have a leading space
                        # when they form an entire "word" (token) following another word.
                        no_leading_space_punctuation = {
                            ",", ".", ";", ":", "!", "?",        # Standard sentence punctuation
                            ")", "]", "}",                     # Closing brackets
                            "'s", "'S", "'re", "'RE", "'ve", "'VE", # Common contractions
                            "'m", "'M", "'ll", "'LL", "'d", "'D",
                            "n't", "N'T",
                            "...", "…"                          # Ellipses
                        }
                        if current_word not in no_leading_space_punctuation:
                            sys.stdout.write(' ')
                            self.current_line_length += 1
                    sys.stdout.write(current_word)
                    self.current_line_length += len(current_word)

            if delimiter == '\n':
                sys.stdout.write('\n')
                self.current_line_length = 0
            elif delimiter == ' ':
                # If line is full and a space delimiter arrives, it implies a wrap.
                if self.current_line_length >= self.max_length:
                    sys.stdout.write('\n')
                    self.current_line_length = 0

        sys.stdout.flush()

# %%
# @title Formatted streaming example
import sys
from google.colab import ai

class LineWrapper:
    def __init__(self, max_length=80):
        self.max_length = max_length
        self.current_line_length = 0

    def print(self, text_chunk):
        i = 0
        n = len(text_chunk)
        while i < n:
            start_index = i
            while i < n and text_chunk[i] not in ' \n': # Find end of word
                i += 1
            current_word = text_chunk[start_index:i]

            delimiter = ""
            if i < n: # If not end of chunk, we found a delimiter
                delimiter = text_chunk[i]
                i += 1 # Consume delimiter

            if current_word:
                needs_leading_space = (self.current_line_length > 0)

                # Case 1: Word itself is too long for a line (must be broken)
                if len(current_word) > self.max_length:
                    if needs_leading_space: # Newline if current line has content
                        sys.stdout.write('\n')
                        self.current_line_length = 0
                    for char_val in current_word: # Break the long word
                        if self.current_line_length >= self.max_length:
                            sys.stdout.write('\n')
                            self.current_line_length = 0
                        sys.stdout.write(char_val)
                        self.current_line_length += 1
                # Case 2: Word doesn't fit on current line (print on new line)
                elif self.current_line_length + (1 if needs_leading_space else 0) + len(current_word) > self.max_length:
                    sys.stdout.write('\n')
                    sys.stdout.write(current_word)
                    self.current_line_length = len(current_word)
                # Case 3: Word fits on current line
                else:
                    if needs_leading_space:
                        # Define punctuation that should not have a leading space
                        # when they form an entire "word" (token) following another word.
                        no_leading_space_punctuation = {
                            ",", ".", ";", ":", "!", "?",        # Standard sentence punctuation
                            ")", "]", "}",                     # Closing brackets
                            "'s", "'S", "'re", "'RE", "'ve", "'VE", # Common contractions
                            "'m", "'M", "'ll", "'LL", "'d", "'D",
                            "n't", "N'T",
                            "...", "…"                          # Ellipses
                        }
                        if current_word not in no_leading_space_punctuation:
                            sys.stdout.write(' ')
                            self.current_line_length += 1
                    sys.stdout.write(current_word)
                    self.current_line_length += len(current_word)

            if delimiter == '\n':
                sys.stdout.write('\n')
                self.current_line_length = 0
            elif delimiter == ' ':
                # If line is full and a space delimiter arrives, it implies a wrap.
                if self.current_line_length >= self.max_length:
                    sys.stdout.write('\n')
                    self.current_line_length = 0

        sys.stdout.flush()

wrapper = LineWrapper()
for chunk in ai.generate_text('Liệt kê chi tiết và giải thích một số hành vi không chuẩn mực trong lớp học.', model_name='google/gemini-2.5-flash', stream=True):
  wrapper.print(chunk)
# Out:
# Trong môi trường học đường, các hành vi không chuẩn mực là những hành động của
# học sinh đi chệch khỏi quy tắc, nội quy chung của lớp học, nhà trường và chuẩn
# mực đạo đức xã hội. Những hành vi này không chỉ ảnh hưởng đến cá nhân người thực
# hiện mà còn tác động tiêu cực đến không khí học tập chung của cả lớp và quá
# trình giảng dạy của giáo viên.
#
# Dưới đây là một số hành vi không chuẩn mực phổ biến trong lớp học, cùng với mô
# tả chi tiết và giải thích về tác động của chúng:
#
# ---
#
# ### **I. Nhóm hành vi gây mất tr ật tự, cản trở giờ học**
#
# 1. **Nói chuyện riêng trong giờ học:**
# * **Mô tả:** Học sinh thì thầm, cười đùa, bàn tán chuyện riêng tư với bạn bè
# hoặc quay sang trò chuyện khi giáo viên đang giảng bài, khi có bạn phát biểu,
# hoặc khi đang làm bài tập cá nhân.
# * **Giải thích:**
# * **Gây mất tập trung:** Không chỉ bản thân người nói mà cả những bạn xung quanh
# cũng bị xao nhãng, không thể tiếp thu bài giảng một cách hiệu quả.
# * **Cản trở giáo viên:** Làm gián đoạn dòng chảy bài giảng của giáo viên, khiến
# giáo viên phải dừng lại nhắc nhở, làm mất thời gian và sự liên tục của bài học.
# * **Thiếu tôn trọng:** Thể hiện sự thiếu tôn trọng đối với giáo viên và các bạn
# đang chăm chú học tập.
#
# 2. **Gây tiếng ồn (gõ bút, lật sách, di chuyển ghế, nghiến răng, v.v.):**
# * **Mô tả:** Học sinh tạo ra những âm thanh không cần thiết và khó chịu như gõ
# bút liên tục xuống bàn, lật sách ồn ào, kéo ghế rầm rầm, nghiến răng, búng tay,
# hoặc tạo ra các tiếng động lạ khác.
# * **Giải thích:**
# * **Phá vỡ không gian yên tĩnh:** Học tập đòi hỏi sự tập trung cao độ, những
# tiếng ồn dù nhỏ cũng có thể làm gián đoạn tư duy của người khác.
# * **Khó chịu cho người xung quanh:** Gây ức chế, khó chịu cho bạn bè và giáo
# viên, ảnh hưởng đến tâm trạng và khả năng tiếp thu bài.
#
# 3. **Di chuyển lung tung, rời chỗ không xin phép:**
# * **Mô tả:** Học sinh tự ý đứng dậy đi lại trong lớp, ra ngoài hành lang, xuống
# bàn bạn bè để mượn đồ hoặc trò chuyện mà không có sự cho phép của giáo viên.
# * ** Giải thích:**
# * **Gây gián đoạn:** Làm xao nhãng sự chú ý của các bạn khác, đặc biệt khi có
# người đi qua lại trong tầm nhìn.
# * **Nguy hiểm (đôi khi):** Trong một số hoạt động, việc di chuyển lung tung có
# thể gây va chạm hoặc nguy hiểm nhỏ.
# * **Phá vỡ quy tắc:** Thể hiện thái độ thiếu kỷ luật, không tuân thủ nội quy lớp
# học.
#
# 4. **Sử dụng thiết bị điện tử sai mục đích (điện thoại, máy tính bảng):**
# * **Mô tả:** Học sinh lén lút chơi game, nhắn tin, lướt mạng xã hội, xem video,
# nghe nhạc hoặc thực hiện các hoạt động giải trí khác trên điện thoại/máy tính
# bảng trong giờ học thay vì dùng cho mục đích học tập.
# * **Giải thích:**
# * **Mất tập trung hoàn toàn:** Học sinh không thể đồng thời tiếp thu bài giảng
# và sử dụng thiết bị điện tử cho mục đích giải trí.
# * **Ảnh hưởng thị lực và sức khỏe:** Sử dụng điện thoại liên tục trong môi
# trường ánh sáng lớp học không tốt cho mắt.
# * **Tạo tiền lệ xấu:** Khiến các bạn khác cũng muốn bắt chước, làm cho việc quản
# lý lớp học trở nên khó khăn hơn.
#
# 5. **Ăn uống trong lớp (đặc biệt là nhai kẹo cao su, ăn vặt gây mùi):**
# * **Mô tả:** Học sinh ăn nhẹ, nhai kẹo cao su, uống nước ngọt hoặc ăn vặt có mùi
# trong giờ học.
# * **Giải thích:**
# * **Mất tập trung:** Việc ăn uống làm phân tán sự chú ý vào bài giảng.
# * **G ây tiếng ồn và mùi:** Tiếng nhai, tiếng mở gói đồ ăn hoặc mùi thức ăn có
# thể gây khó chịu cho người xung quanh.
# * **Vệ sinh:** Dễ làm rơi vãi thức ăn, gây mất vệ sinh lớp học.
#
# 6. **Ngủ gật, l ơ đễnh, không chú ý bài giảng:**
# * **Mô tả:** Học sinh gục đầu ngủ gật, mơ màng nhìn ra ngoài cửa sổ, hoặc có
# biểu hiện không quan tâm đến nội dung bài học.
# * **Giải thích:**
# * **Không tiếp thu kiến thức:** Học sinh bỏ lỡ các thông tin quan trọng, dẫn đến
# hổng kiến thức và kết quả học tập kém.
# * **Thiếu tôn trọng:** Thể hiện sự thiếu tôn trọng đối với công sức chuẩn bị bài
# giảng của giáo viên.
# * **Ảnh hưởng không khí học tập:** Có thể làm giáo viên nản lòng và ảnh hưởng
# đến tinh thần học tập chung của lớp.
#
# ---
#
# ### **II. Nhóm hành vi thiếu tôn trọng và thiếu trách nhiệm**
#
# 1. **Cãi lại giáo viên, bạn bè:**
# * **Mô tả:** Học sinh dùng lời lẽ thách thức, không vâng lời, hoặc có thái độ
# chống đối khi được giáo viên hoặc bạn bè góp ý, nhắc nhở.
# * **Giải thích:**
# * **Phá vỡ kỷ luật:** Làm suy yếu uy tín của giáo viên và phá vỡ kỷ luật lớp học
# .
# * **Gây xung đột:** Có thể dẫn đến mâu thuẫn, căng thẳng trong mối quan hệ giữa
# học sinh và giáo viên, hoặc giữa các học sinh với nhau.
# * **Ảnh hưởng môi trường:** Tạo ra một môi trường học tập không an toàn, thiếu
# sự tôn trọng lẫn nhau.
#
# 2. **Không chuẩn bị bài, không làm bài tập:**
# * **Mô tả:** Học sinh không đọc bài trước ở nhà, không làm các bài tập được
# giao, hoặc không mang đầy đủ sách vở, dụng cụ học tập.
# * ** Giải thích:**
# * **Cản trở việc học:** Học sinh không có kiến thức nền tảng để theo kịp bài
# giảng, dẫn đến khó hiểu bài và điểm số thấp.
# * **Ảnh hưởng đến hoạt động nhóm:** Nếu có hoạt động nhóm, việc một thành viên
# không chuẩn bị sẽ làm ảnh hưởng đến tiến độ và chất lượng công việc chung.
# * **Thiếu trách nhiệm:** Thể hiện sự thiếu trách nhiệm với việc học của bản
# thân.
#
# 3. **Đi học muộn, về sớm không xin phép:**
# * **Mô tả:** Học sinh đến lớp sau khi giờ học đã bắt đầu hoặc tự ý rời khỏi lớp
# trước khi giờ học kết thúc mà không có lý do chính đáng và không được sự cho
# phép của giáo viên.
# * **Giải thích:**
# * **Gây gián đoạn:** Việc ra vào lớp làm gián đoạn sự tập trung của giáo viên và
# các bạn.
# * **Bỏ lỡ thông tin:** Học sinh đi muộn hoặc về sớm sẽ bỏ lỡ phần đầu hoặc phần
# cuối của bài giảng, ảnh hưởng đến việc tiếp thu kiến thức.
# * **Thiếu kỷ luật:** Thể hiện sự thiếu tôn trọng thời gian và quy định của lớp
# học.
#
# 4. **Quay cóp, gian lận trong kiểm tra, thi cử:**
# * **Mô tả:** Học sinh sử dụng tài liệu không được phép, nhìn bài bạn, trao đổi
# bài trong khi làm bài kiểm tra hoặc thi.
# * **Giải thích:**
# * **Hủy hoại giá trị học tập:** Làm mất đi ý nghĩa của việc đánh giá năng lực
# thực sự của học sinh.
# * **Thiếu trung thực:** Hình thành thói quen không trung thực, gian dối.
# * **Ảnh hưởng công bằng:** Gây mất công bằng cho những học sinh trung thực, cố
# gắng học tập.
#
# 5. **Bắt nạt, trêu chọc bạn bè:**
# * **Mô tả:** Học sinh có hành vi chế giễu, xúc phạm, cô lập, đ e dọa hoặc dùng
# bạo lực thể chất/lời nói với bạn bè trong lớp.
# * **Giải thích:**
# * **Gây tổn thương tâm lý:** Khiến nạn nhân cảm thấy sợ hãi, lo lắng, bị cô lập,
# ảnh hưởng nghiêm trọng đến tinh thần và khả năng học tập.
# * **Phá hoại môi trường học tập:** Tạo ra một không khí căng thẳng, không an
# toàn trong lớp học.
# * **Vi phạm đạo đức:** Là hành vi vô cùng sai trái, vi phạm chuẩn mực đạo đức xã
# hội.
#
# 6. **Phá hoại tài sản chung (bàn ghế, bảng, thiết bị):**
# * **Mô tả:** Học sinh vẽ bậy lên bàn, ghế, tường; làm hỏng thiết bị học tập;
# hoặc có hành vi phá hoại tài sản của nhà trường hoặc của bạn bè.
# * **Giải thích:**
# * **Gây thiệt hại:** Làm hư hỏng tài sản, gây tốn kém chi phí sửa chữa hoặc thay
# thế.
# * **Ảnh hưởng môi trường:** Làm mất mỹ quan lớp học, ảnh hưởng đến điều kiện học
# tập chung.
# * **Thiếu ý thức:** Thể hiện sự thiếu ý thức giữ gìn của công.
#
# ---
#
# **Kết luận:**
#
# Việc nhận diện và giải thích rõ ràng về các hành vi không chuẩn mực trong lớp
# học là bước đầu tiên quan trọng để giáo viên và học sinh cùng nhau xây dựng một
# môi trường học tập tích cực, kỷ luật và hiệu quả. M ọi hành vi đều cần được nhìn
# nhận một cách khách quan, và việc giáo dục, hướng dẫn học sinh sửa đổi hành vi
# là trách nhiệm chung của nhà trường, gia đình và xã hội.

# %% [markdown]
# # Task
# Giải thích đoạn mã Python trong ô đã chọn (R7taibpc7x2l).

# %% [markdown]
# ## explain_code_cell
#
# ### Subtask:
# Giải thích đoạn mã Python trong ô đã chọn (R7taibpc7x2l) cho người dùng.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The agent initiated the `explain_code_cell` subtask to provide an explanation for the Python code within the specified cell (R7taibpc7x2l). A text cell was added to document this subtask.
#
# ### Data Analysis Key Findings
# - The `explain_code_cell` subtask was initiated to analyze and clarify the functionality of the Python code in cell R7taibpc7x2l.
# - A descriptive text cell was generated and added to the notebook, outlining the purpose of the ongoing subtask.
#
# ### Insights or Next Steps
# - The next step is to generate and present the actual explanation of the Python code in cell R7taibpc7x2l, detailing its functionality and purpose.
